# %%
# Write a program to demonstrate the Quiz Game.

Que_dic = {}

def master_work():
    while True:
        ms_in = input("""
        WELCOME MASTER
        MENU
        1)ADD QUESTION
        2)VIEW QUESTION
        3)DELETE QUESTION
        4)EXIT
        """)
        if ms_in =='1':#add question
            que = input('Enter Your Question')
            op1 = input('Enter Option 1:')
            op2 = input('Enter Option 2:')
            ans = input('Enter correct Answer')
            nest_dic = {'question': que, 'op1': op1, 'op2': op2, 'ans': ans}
            Que_dic.update({len(Que_dic)+1: nest_dic})
            
        elif ms_in == '2': #view question
            for i in Que_dic:
                print(str(i)+')', Que_dic[i]['question'])
        
        elif ms_in == '3': # delete question
            while True:
                print('Please select Question Number From Bellow :)')
                for i in Que_dic:
                    print(str(i)+')', Que_dic[i]['question'])
                del_in = input()
                if del_in.isdigit():
                    if Que_dic.get(int(del_in)):
                        Que_dic.pop(int(del_in))
                        print('deleted successfully')
                        break
                    else:
                        print('Question Not Found Enter again :)')
                        
                else:
                    print('Invalid Input Enter Again')
        elif ms_in == '4';#exit
            break
        else:
            print('Invalid Input Enter Again :')
                    
def player_work():
    print("""
    WEL-COME PLAYER
    """)
    SCORE = 0
    for i in Que_dic:
        while True:
            print(Que_dic[i]['question'])
            print('a.' , Que_dic[i]['op1'])
            print('b.' , Que_dic[i]['op2'])
            pl_an = input('Select option')
            if pl_an == 'a':
                if Que_dic[i]['anss'] == Que_dic[i]['op1']:
                    SCORE += 1
                    print(f'Your answer is Right score is {SCORE}')
                    break
                else:
                    print(f'Your anser is wrong...\ncurrent score:{SCORE}')
                    break
            elif pl_an == 'b':
                if Que_dic[i]['anss'] == Que_dic[i]['op2']:
                    SCORE += 1
                    print(f'Your answer is Right score is {SCORE}')
                    break
                else:
                    print(f'Your anser is wrong...\ncurrent score:{SCORE}')
                    break
            else:
                print('Invalid Input Please Enter Again')
                
    return score   
#main loop... execute when program is started.

final = True
while final:
    op = input("\n\t\t\t WELCOME TO TOPS QUIZ GAME CHALLANGE \n\t\t1). Master\n\t\t2). Player")
    if op == '1':
        master_work()
        print('All set sir')
     
    elif op == '2':
        final_score = player_work()
        print(f'Hurrry Your score is {final_score}')
        while True:
            f_c = input('Do you want to exit the game?(y/n):')
            if f_c == 'y':
                print('OK Sir')
                final = False
                break
            elif f_c == 'n':
                break
            else:
                    print('Please Enter Valid Input')
    else:
        print('Invalid Input , Enter Again')
# Out:
#   Cell In[1], line 43
#     elif ms_in == '4';#exit
#                      ^
# SyntaxError: invalid syntax
